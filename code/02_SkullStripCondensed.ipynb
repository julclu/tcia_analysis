# %% [markdown]
# ## Skullstrip only the niftis that are in the final analysis

# %% [markdown]
# For each exam, we want to find the T1, T2, T2FLAIR, and T1C and for the first go, we're just going to skull strip using the BET program from FSL.

# %% [markdown]
# We want to use the following command:
#
# ` bet <input> <output> -S`

# %%
import glob
import subprocess as sub 
from subprocess import * 
import os 
from pathlib import Path
import pandas as pd

# %% [markdown]
# We can use the output from a prior analysis to label our images:

# %%
PATH = Path('/working/lupolab/julia/tcia_analysis/')

# %%
aligned_dti = pd.read_csv(Path(PATH, 'code', 'aligned_dti.csv'))

# %%
aligned_dti.head()
# Out:
#            cohort                                                dti  \
# 0  TCGA-LGG-nifti  ['400-DTI_2.6mm_WH-19253.nii.gz', '4-DTI_2.6mm...
# 1  TCGA-LGG-nifti                          ['205-dadc-52244.nii.gz']
# 2  TCGA-LGG-nifti  ['12-ep2ddiffmddw20p2_wipADC-35015.nii.gz', '1...
# 3  TCGA-LGG-nifti  ['601-DTI_ASSET-84919.nii.gz', '600-DTI_ASSET-...
# 4  TCGA-LGG-nifti  ['501-DTI_2.6mm_WH-21034.nii.gz', '5-DTI_2.6mm...
#
#                                       exam    patient_id  \
# 0  08-23-1995-MRI_BRAIN_WWO_CONTRAST-78436  TCGA-DU-5853
# 1         06-01-2000-MRI_BRAIN_per_R-97608  TCGA-CS-6186
# 2        04-23-2004-NR_MRI_BRAIN_WWO-08141  TCGA-FG-A6J1
# 3   06-18-1989-MRI_BRAIN_WWO_CONTRAS-16160  TCGA-DU-7015
# 4  01-11-1997-MRI_BRAIN_WWO_CONTRAST-98366  TCGA-DU-8164
#
#                  segmentation_name  \
# 0  11-AX_T1_POST_GD_FLAIR-81300a_n
# 1         1001-T1_SE_POST-94212a_n
# 2         20-T1fl2dAx__Gd-43129a_n
# 3  10-AX_T1_POST_GD_FLAIR-19430a_n
# ...

# %%
commands_premask = []
commands_skullstrip = []
for idx, row in aligned_dti.iterrows():
    cohort  = row['cohort']
    patient = row['patient_id']
    exam    = row['exam']
    path_to_exam = Path(PATH, 'datasets', cohort, patient, exam)
    
    all_old_vols = glob.glob(str(path_to_exam)+'/*a.nii.gz')
    print(all_old_vols)
    
    for old_vol in all_old_vols: 
        premask_vol = old_vol.split('.n')[0]+'_premask'+'.nii.gz'
        output_vol  = old_vol.split('.n')[0]+'_n'+'.nii.gz'
        command_premask = 'standard_space_roi '+old_vol+' '+premask_vol+' -b'
        command_skullstrip = 'bet '+premask_vol+' '+output_vol+' -f 0.2'
        commands_premask.append(command_premask)
        commands_skullstrip.append(command_skullstrip)
# Out:
# ['/working/lupolab/julia/tcia_analysis/datasets/TCGA-LGG-nifti/TCGA-DU-5853/08-23-1995-MRI_BRAIN_WWO_CONTRAST-78436/8-AX_T1_pre_gd-14019a.nii.gz', '/working/lupolab/julia/tcia_analysis/datasets/TCGA-LGG-nifti/TCGA-DU-5853/08-23-1995-MRI_BRAIN_WWO_CONTRAST-78436/9-3D_DCE_T1_MAP-73753a.nii.gz', '/working/lupolab/julia/tcia_analysis/datasets/TCGA-LGG-nifti/TCGA-DU-5853/08-23-1995-MRI_BRAIN_WWO_CONTRAST-78436/7-AX_T2_FR-FSE_RF2_150-55295a.nii.gz', '/working/lupolab/julia/tcia_analysis/datasets/TCGA-LGG-nifti/TCGA-DU-5853/08-23-1995-MRI_BRAIN_WWO_CONTRAST-78436/12-COR__T1_POST_GD_FLAIR-32689a.nii.gz', '/working/lupolab/julia/tcia_analysis/datasets/TCGA-LGG-nifti/TCGA-DU-5853/08-23-1995-MRI_BRAIN_WWO_CONTRAST-78436/TCGA-DU-5853_adca.nii.gz', '/working/lupolab/julia/tcia_analysis/datasets/TCGA-LGG-nifti/TCGA-DU-5853/08-23-1995-MRI_BRAIN_WWO_CONTRAST-78436/3-SAG_T1_FLAIR-94337a.nii.gz', '/working/lupolab/julia/tcia_analysis/datasets/TCGA-LGG-nifti/TCGA-DU-5853/08-23-1995-MRI_BRAIN_WWO_CONTRA
# ...

# %%
commands_premask
# Out:
# ['standard_space_roi /working/lupolab/julia/tcia_analysis/datasets/TCGA-LGG-nifti/TCGA-DU-5853/08-23-1995-MRI_BRAIN_WWO_CONTRAST-78436/8-AX_T1_pre_gd-14019a.nii.gz /working/lupolab/julia/tcia_analysis/datasets/TCGA-LGG-nifti/TCGA-DU-5853/08-23-1995-MRI_BRAIN_WWO_CONTRAST-78436/8-AX_T1_pre_gd-14019a_premask.nii.gz -b',
#  'standard_space_roi /working/lupolab/julia/tcia_analysis/datasets/TCGA-LGG-nifti/TCGA-DU-5853/08-23-1995-MRI_BRAIN_WWO_CONTRAST-78436/9-3D_DCE_T1_MAP-73753a.nii.gz /working/lupolab/julia/tcia_analysis/datasets/TCGA-LGG-nifti/TCGA-DU-5853/08-23-1995-MRI_BRAIN_WWO_CONTRAST-78436/9-3D_DCE_T1_MAP-73753a_premask.nii.gz -b',
#  'standard_space_roi /working/lupolab/julia/tcia_analysis/datasets/TCGA-LGG-nifti/TCGA-DU-5853/08-23-1995-MRI_BRAIN_WWO_CONTRAST-78436/7-AX_T2_FR-FSE_RF2_150-55295a.nii.gz /working/lupolab/julia/tcia_analysis/datasets/TCGA-LGG-nifti/TCGA-DU-5853/08-23-1995-MRI_BRAIN_WWO_CONTRAST-78436/7-AX_T2_FR-FSE_RF2_150-55295a_premask.nii.gz -b',
# ...

# %%
os.chdir('/working/lupolab/julia/tcia_analysis/code/')

# %%
# !rm skullstrip_condensed.txt
# Out:
# rm: cannot remove ‘skullstrip_condensed.txt’: No such file or directory

# %%
x = open('skullstrip_condensed.txt', 'w')

# %%
x.write('{')
x.write('\n')
for command in commands_skullstrip: 
    x.write(command)
    x.write('\n')
x.write('}')
x.close()

# %%
# !grid_pipeline --scriptonly skullstrip_condensed.txt

# %%
x = open('premask_condensed.txt', 'w')
x.write('{')
x.write('\n')
for command in commands_premask: 
    x.write(command)
    x.write('\n')
x.write('}')
x.close()

# %%
# !grid_pipeline --scriptonly premask_condensed.txt

# %%
commands_skullstrip = []
for idx, row in aligned_dti.iterrows():
    cohort  = row['cohort']
    patient = row['patient_id']
    exam    = row['exam']
    path_to_exam = Path(PATH, 'datasets', cohort, patient, exam)
    
    all_old_vols = glob.glob(str(path_to_exam)+'/*a.nii.gz')
#     print(all_old_vols)
    
    for old_vol in all_old_vols: 
        output_vol  = old_vol.split('.n')[0]+'_n'+'.nii.gz'
        command_skullstrip = 'bet '+old_vol+' '+output_vol+' -f 0.5 -S'
        commands_skullstrip.append(command_skullstrip)

# %%
x = open('skullstrip_condensed_stripOnly.txt', 'w')
x.write('{')
x.write('\n')
for command in commands_skullstrip: 
    x.write(command)
    x.write('\n')
x.write('}')
x.close()

# %%
# !grid_pipeline --scriptonly skullstrip_condensed_stripOnly.txt
