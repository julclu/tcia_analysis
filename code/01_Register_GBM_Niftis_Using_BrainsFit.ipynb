# %% [markdown]
# ## Registering the GBM NIFTIS

# %% [markdown]
# For each exam, we want to register everything to the following (in order):
# 1. T1 pre-contrast Ax
# 2. T1 post-contrast Ax
# 3. T2 FSE Ax
# 4. T1 (other orientation) post-contrast
# 5. T2 FSE (other orientation)
# 6. T2 FLAIR Ax
# 7. T2 FLAIR (other orientation)

# %% [markdown]
# We want to use the following command:
#
# ` BRAINSFit --fixedVolume $fixed_vol.nii.gz --movingVolume $moving_vol.nii.gz --outputVolume $output_vol.nii.gz --outputTransform $transform_output.tfm  --transformType Rigid`

# %% [markdown]
# But first we need to figure out which are the fixed volumes; this will require labeling.

# %% [markdown]
# Let's use code derived from `http://localhost:8890/notebooks/data/svcf/labels/TCGA-GBM/GenerateGroundTruthUsingDCMdump.ipynb`

# %% [markdown]
# This function will take in a patient file and output whether the T1 images have contrast:

# %%
import glob
import subprocess as sub 
from subprocess import * 
import os 
from pathlib import Path
import pandas as pd

# %%
def find_if_t1_image_has_contrast(outfile, root_dir): 
    patient_images = glob.glob(str(root_dir)+ '/TCGA-GBM/'+outfile.split('.')[0]+"/*/*")
    
    image_contrast_map = {}
    for j in patient_images: 
        os.chdir(j)
#         print(j)
        command = "dcmdump 000000.dcm | grep -i '(0018,0010)' "
        result = sub.Popen(command, stdout=sub.PIPE, stderr = sub.PIPE, shell = True)
        out, err = result.communicate()
        out = out.decode('utf-8')
        if out: 
            image_contrast_map[j.split('/')[-1].split('.d')[0]] = 1
        else: 
            image_contrast_map[j.split('/')[-1].split('.d')[0]] = 0
            
    return image_contrast_map

# %%
root_dir = Path("/working/lupolab/julia/tcia_analysis/datasets/")

# %%
image_contrast_map = find_if_t1_image_has_contrast('TCGA-14-1037', root_dir)

# %%
image_contrast_map
# Out:
# {'501-BRAIN_WWO_FLAIR_AX-83511': 0,
#  '701-BRAIN_WWO_T1_COR_POST-66263': 0,
#  '301-BRAIN_WWO_T1_AX_PRE-93802': 0,
#  '101-BRAIN_WWO_mst_scout-48026': 0,
#  '401-BRAIN_WWO_T2_AX_GRASE-95093': 0,
#  '201-BRAIN_WWO_T1_SAG_23SL-40460': 0,
#  '601-BRAIN_WWO_T1_AX_POST-37152': 0,
#  '501-BRAIN_WOW_FLAIR_AX-95449': 0,
#  '302-BRAIN_WOW_SS_DIFF-74691': 0,
#  '901-BRAIN_WOW_tumor_volume-17835': 0,
#  '601-BRAIN_WOW_T2_GRASE_AX-58314': 0,
#  '301-BRAIN_WOW_SS_DIFF-65178': 0,
#  '101-BRAIN_WOW_SURVEYMST-80576': 0,
#  '701-BRAIN_WOW_AX_T1_POST-67235': 0,
#  '201-BRAIN_WOW_T1_SAG-86994': 0,
#  '401-BRAIN_WOW_AX_T1_PRE-09505': 0,
#  '801-BRAIN_WOW_COR_T1_POST-06833': 0,
#  '301-BRAIN_WOW_FLAIR_AX-65160': 0,
#  '101-BRAIN_WOW_SURVEYMST-09088': 0,
#  '701-BRAIN_WOW_AX_T1_POST-41621': 0,
#  '201-BRAIN_WOW_T1_SAG-43616': 0,
#  '501-BRAIN_WOW_AX_T1_PRE-77719': 0,
#  '401-BRAIN_WOW_T2_GRASE_AX-82731': 0,
#  '601-BRAIN_WOW_HEMOSIDERIN-16533': 0,
#  '801-BRAIN_WOW_COR_T1_POST-93302': 0,
#  '901-BRAIN_WOW_COR_T1_POST-57997': 0,
#  '801-BRAIN_WWO_T1_PRE-85419': 0,
#  '301-BRAIN_WWO_T1_SAG-67114': 0,
#  '501-BRAIN_WWO_FLAIR-21895': 0,
#  '701-BRAIN_WWO_T2_HEMOSID-99784': 0,
#  '1001-BRAIN_WWO_COR_POST-63687': 0,
#  '901-BRAIN_WWO_T1_POST-28914': 0,
#  '401-BRAIN_WWO_SS_DWI-24879': 0,
#  '402-BRAIN_WWO_SS_DWI-44711': 0,
#  '601-BRAIN_WWO_T2_GRASE-17639': 0,
#  '601-BRAIN_WWO_T1_AX_Post-16133': 0,
#  '501-BRAIN_WWO_FLAIR_AX-49548': 0,
#  '201-BRAIN_WWO_T1_SAG_23SL-29091': 0,
#  '101-BRAIN_WWO_mst_scout-13420': 0,
#  '301-BRAIN_WWO_T1_AX_PRE-02708': 0,
#  '801-BRAIN_WWO_TUMOR_VOLUME-27818': 0,
#  '701-BRAIN_WWO_T1_COR_POST-49219': 0,
#  '401-BRAIN_WWO_T2_AX_GRASE-36142': 0,
#  '801-BRAIN_WOW_COR_T1_POST-92337': 0,
#  '301-BRAIN_WOW_FLAIR_AX-00925': 0,
#  '601-BRAIN_WOW_AX_T1_PRE-57023': 0,
#  '201-BRAIN_WOW_T1_SAG-62693': 0,
#  '901-BRAIN_WOW_tumor_volume-15204': 0,
#  '501-BRAIN_WOW_SS_DIFF-50257': 0,
#  '401-BRAIN_WOW_T2_GRASE_AX-98893': 0,
#  '502-BRAIN_WOW_SS_DIFF-97687': 0,
#  '701-BRAIN_WOW_AX_T1_POST-60092': 0,
#  '101-BRAIN_WOW_SURVEYMST-56208': 0,
#  '601-brain_with_AX_T1_POST-65155': 0,
#  '101-brain_with_mst_scout-63247': 0,
#  '301-brain_with_Ax_T1_Pre-40055': 0,
#  '501-brain_with_T2_AX_GRASE-04582': 0,
#  '401-brain_with_FLAIR-42301': 0,
#  '201-brain_with_T1_SAG_23SL-94734': 0,
#  '801-brain_with_TUMOR_VOLUME-86333': 0,
#  '701-brain_with_Cor_T1_Post-44289': 0,
#  '101-BRAIN_WWO_mst_scout-65713': 0,
#  '301-BRAIN_WWO_T1_AX_PRE-48507': 0,
#  '801-BRAIN_WWO_TUMOR_VOLUME-77029': 0,
#  '601-BRAIN_WWO_T1_AX_POST-44604': 0,
#  '401-BRAIN_WWO_T2_AX_GRASE-98745': 0,
#  '501-BRAIN_WWO_FLAIR_AX-80307': 0,
#  '701-BRAIN_WWO_T1_COR_POST-29894': 0,
#  '201-BRAIN_WWO_T1_SAG_23SL-42232': 0,
#  '3-Recon_2-25732': 0,
#  '1-53548': 0,
#  '2-00860': 0,
#  '301-brain_with_Ax_T1_Pre-19546': 0,
#  '602-brain_with_SS_DWI-09624': 0,
#  '501-brain_with_T2_AX_GRASE-59250': 0,
#  '601-brain_with_SS_DWI-76315': 0,
#  '201-brain_with_T1_SAG_23SL-82568': 0,
#  '901-brain_with_TUMOR_VOLUME-26823': 0,
#  '101-brain_with_mst_scout-81003': 0,
#  '401-brain_with_FLAIR-92381': 0,
#  '801-brain_with_Cor_T1_Post-24248': 0,
#  '701-brain_with_AX_T1_POST-82850': 0,
#  '801-BRAIN_WWO_TUMOR_VOLUME-97023': 0,
#  '701-BRAIN_WWO_T1_COR_POST-18213': 0,
#  '501-BRAIN_WWO_FLAIR_AX-41775': 0,
#  '201-BRAIN_WWO_T1_SAG_23SL-26737': 0,
#  '301-BRAIN_WWO_T1_AX_PRE-47069': 0,
#  '101-BRAIN_WWO_mst_scout-44377': 0,
#  '601-BRAIN_WWO_T1_AX_POST-94443': 0,
#  '401-BRAIN_WWO_T2_AX_GRASE-46170': 0,
#  '101-BRAIN_WWO_mst_scout-29783': 0,
#  '701-BRAIN_WWO_T1_COR_POST-75138': 0,
#  '301-BRAIN_WWO_T1_AX_PRE-31718': 0,
#  '201-BRAIN_WWO_T1_SAG_23SL-85927': 0,
#  '501-BRAIN_WWO_FLAIR_AX-81830': 0,
#  '401-BRAIN_WWO_T2_AX_GRASE-06695': 0,
#  '601-BRAIN_WWO_T1_AX_POST-65480': 0,
#  '601-BRAIN_WWO-79396': 1,
#  '201-BRAIN_WOW_tumor_volume-07318': 0,
#  '401-BRAIN_WWO-60700': 1,
#  '501-BRAIN_WWO-76641': 1,
#  '801-mra_abd-83512': 1,
#  '701-BRAIN_WWO-56269': 1,
#  '402-BRAIN_WWO-67884': 1,
#  '1001-BRAIN_WWO-76500': 1,
#  '901-BRAIN_WWO-90003': 1,
#  '1101-BRAIN_WWO-24565': 1,
#  '301-BRAIN_WWO-74478': 1,
#  '201-SYRYKER____STRYKER-59438': 0,
#  '101-SYRYKER____mst_scout-37372': 0}

# %%
outfile = 'TCGA-14-1037'

# %%
outfile.split('.')[0]
# Out:
# 'TCGA-14-1037'

# %%
# for image in patient_images: 
#     series_description = image.split('/')[-1].split('.')[0]
#     print(series_description)

# %%
str(root_dir)+ '/TCGA-GBM-nifti/'+outfile.split('.')[0]+"/*/*"
# Out:
# '/working/lupolab/julia/tcia_analysis/datasets/TCGA-GBM-nifti/TCGA-14-1037/*/*'

# %%
patient_images = glob.glob(str(root_dir)+ '/TCGA-GBM-nifti/'+outfile.split('.')[0]+"/*/*")

# %%
patient_images
# Out:
# ['/working/lupolab/julia/tcia_analysis/datasets/TCGA-GBM-nifti/TCGA-14-1037/03-31-1995-MRI_BRAIN_W_WOUT_CONTRAST-67779/701-BRAIN_WOW_AX_T1_POST-60092a.nii.gz',
#  '/working/lupolab/julia/tcia_analysis/datasets/TCGA-GBM-nifti/TCGA-14-1037/03-31-1995-MRI_BRAIN_W_WOUT_CONTRAST-67779/201-BRAIN_WOW_T1_SAG-62693a_n.nii.gz',
#  '/working/lupolab/julia/tcia_analysis/datasets/TCGA-GBM-nifti/TCGA-14-1037/03-31-1995-MRI_BRAIN_W_WOUT_CONTRAST-67779/201-BRAIN_WOW_T1_SAG-62693.nii.gz',
#  '/working/lupolab/julia/tcia_analysis/datasets/TCGA-GBM-nifti/TCGA-14-1037/03-31-1995-MRI_BRAIN_W_WOUT_CONTRAST-67779/401-BRAIN_WOW_T2_GRASE_AX-98893a.nii.gz',
#  '/working/lupolab/julia/tcia_analysis/datasets/TCGA-GBM-nifti/TCGA-14-1037/03-31-1995-MRI_BRAIN_W_WOUT_CONTRAST-67779/401-BRAIN_WOW_T2_GRASE_AX-98893a_n.nii.gz',
#  '/working/lupolab/julia/tcia_analysis/datasets/TCGA-GBM-nifti/TCGA-14-1037/03
working/lupolab/julia/tcia_analysis/datasets/TCGA-GBM-nifti/TCGA-14-1037/01-08-1995-STRYKER_BRAIN-11902/101-SYRYKER____mst_scout-37372.nii.gz']

# %%
def create_single_label_dataframe(outfile, image_contrast_map): 
    
    patient_images = glob.glob(str(root_dir)+ '/TCGA-GBM-nifti/'+outfile.split('.')[0]+"/*/*")
    if patient_images: 
        #instantiate new label: 
        newlabel_df = pd.DataFrame()

        #cycle thru items in label, 
        for image in patient_images: 

            series_description = image.split('/')[-1].split('.n')[0]

            if 't1' in series_description.lower() or 'spgr' in series_description.lower(): 
                if image_contrast_map[series_description] == 1: 
                    new_gt = 'T1C'

                elif 'post' in series_description.lower(): 
                    new_gt = 'T1C'

                else: 
                    new_gt = "T1"
            elif 'flair' in series_description.lower() and 't1' not in series_description.lower(): 
                new_gt = 'T2_FLAIR'
            elif ('t2' in series_description.lower() or 'fse' in series_description.lower() )and 'flair' not in series_description.lower() and 'dw' not in series_description.lower(): 
                new_gt = 'T2'

            else: 
                new_gt = 'OTHER'

            newlabel_df_line = {'image': image, 'sd': series_description, 'ground_truth': new_gt}
    #         print(newlabel_df_line)
            newlabel_df = newlabel_df.append(newlabel_df_line, ignore_index = True)

        return newlabel_df
    else: 
        return None

# %%
df_example = create_single_label_dataframe(outfile, image_contrast_map)
# Out:
# ------------------------------------------------------------------------
# KeyError                               Traceback (most recent call last)
# <ipython-input-13-8f370d93b2cc> in <module>
# ----> 1 df_example = create_single_label_dataframe(outfile, image_contrast_map)
#
# <ipython-input-12-35c33debe212> in create_single_label_dataframe(outfile, image_contrast_map)
#      12
#      13             if 't1' in series_description.lower() or 'spgr' in series_description.lower():
# ---> 14                 if image_contrast_map[series_description] == 1:
#      15                     new_gt = 'T1C'
#      16
#
# KeyError: '701-BRAIN_WOW_AX_T1_POST-60092a'

# %%
df_example

# %%
outfiles = os.listdir('/working/lupolab/julia/tcia_analysis/datasets/TCGA-GBM-nifti')

# %% [markdown]
# Had to remove some of the ones where the conversion to NIFTI broke:

# %%
outfiles.remove('TCGA-19-5951')

# %%
outfiles.remove('TCGA-19-1389')
outfiles.remove('TCGA-19-5952')

# %%
full_label_df = pd.DataFrame()
for outfile in outfiles: 
    print(outfile)
    image_contrast_map = find_if_t1_image_has_contrast(outfile, root_dir)
    single_label_df = create_single_label_dataframe(outfile, image_contrast_map)
    
    full_label_df=full_label_df.append(single_label_df)
# Out:
# TCGA-06-0210
# TCGA-08-0350
# TCGA-14-0865
# ------------------------------------------------------------------------
# KeyError                               Traceback (most recent call last)
# <ipython-input-17-e1d01e92433a> in <module>
#       3     print(outfile)
#       4     image_contrast_map = find_if_t1_image_has_contrast(outfile, root_dir)
# ----> 5     single_label_df = create_single_label_dataframe(outfile, image_contrast_map)
#       6
#       7     full_label_df=full_label_df.append(single_label_df)
#
# <ipython-input-12-35c33debe212> in create_single_label_dataframe(outfile, image_contrast_map)
#      12
#      13             if 't1' in series_description.lower() or 'spgr' in series_description.lower():
# ---> 14                 if image_contrast_map[series_description] == 1:
#      15                     new_gt = 'T1C'
#      16
#
# KeyError: '301-BRAIN_WWO_T1_AX_PRE-13193a_n_skull'

# %%
full_label_df

# %%
full_label_df.image[0]

# %%
full_label_df.to_csv('/working/lupolab/julia/tcia_analysis/labels_tcia_GBM.csv', index = False)

# %%
full_label_df = pd.read_csv('/working/lupolab/julia/tcia_analysis/labels_tcia_GBM.csv')

# %%
full_label_df.head()
# Out:
#   ground_truth                                              image  \
# 0        OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 1           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 2           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 3          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 4           T2  /working/lupolab/julia/tcia_analysis/datasets/...
#
#                          sd
# 0         1-SAG_LOCAL-29333
# 1          3-AXIAL_T1-88865
# 2          2-AXIAL_T2-83081
# 3  4-AXIAL_T1_POST_GD-64939
# 4      15-3DFSE_AXIAL-04462

# %%
full_label_df.loc[0]['image'].split('/')[7]
# Out:
# 'TCGA-06-0210'

# %%
full_label_df['patient_id'] = [x.split('/')[7] for x in full_label_df.image]

# %%
full_label_df['exam_id'] = [x.split('/')[8] for x in full_label_df.image]

# %%
full_label_df
# Out:
#      ground_truth                                              image  \
# 0           OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 1              T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 2              T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 3             T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 4              T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 5           OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 6              T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 7             T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 8        T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 9             T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 10            T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 11             T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 12          OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 13            T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 14             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 15            T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 16             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 17       T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 18             T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 19          OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 20          OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 21       T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 22             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 23             T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 24          OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 25          OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 26             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 27            T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 28            T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 29             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# ...           ...                                                ...
# 3734        OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 3735           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 3736        OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 3737        OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 3738          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3739        OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 3740        OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 3741        OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 3742        OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 3743           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 3744          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3745        OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 3746     T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 3747           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 3748        OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 3749          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3750          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3751          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3752           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 3753        OTHER  /working/lupolab/julia/tcia_analysis/datasets/...
# 3754           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 3755     T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 3756           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 3757          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3758           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 3759           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 3760           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 3761     T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 3762           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 3763           T1  /working/lupolab/julia/tcia_analysis/datasets/...
#
#                                                      sd    patient_id  \
# 0                                     1-SAG_LOCAL-29333  TCGA-06-0210
# 1                                      3-AXIAL_T1-88865  TCGA-06-0210
# 2                                      2-AXIAL_T2-83081  TCGA-06-0210
# 3                              4-AXIAL_T1_POST_GD-64939  TCGA-06-0210
# 4                                  15-3DFSE_AXIAL-04462  TCGA-08-0350
# 5                    1-TI_SAG_MR_BRAIN_WHOLE_HEAD-52088  TCGA-08-0350
# 6                                   5-3DFSE_AXIAL-96333  TCGA-08-0350
# 7                                   3-FMPSPGR_SAG-00857  TCGA-08-0350
# 8                                   6-FLAIR_AXIAL-64078  TCGA-08-0350
# 9                                  4-3DSPGR_AXIAL-74692  TCGA-08-0350
# 10                                14-3DSPGR_AXIAL-02601  TCGA-08-0350
# 11                              2-FSE_AX_MR_BRAIN-11136  TCGA-08-0350
# 12                        101-BRAIN_WWO_mst_scout-71529  TCGA-14-0865
# 3750     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3751     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3752     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3753     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3754     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3755     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3756     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3757     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3758    11-03-1987-ENCEFALO_ADULTIGENERALE-42337
# 3759    11-03-1987-ENCEFALO_ADULTIGENERALE-42337
# 3760    11-03-1987-ENCEFALO_ADULTIGENERALE-42337
# 3761    11-03-1987-ENCEFALO_ADULTIGENERALE-42337
# 3762    11-03-1987-ENCEFALO_ADULTIGENERALE-42337
# 3763    11-03-1987-ENCEFALO_ADULTIGENERALE-42337
#
# [3764 rows x 5 columns]

# %%
patient_list = full_label_df.patient_id.unique()

# %%
len(patient_list)
# Out:
# 193

# %%
usable_patients = []
for patient in patient_list: 
    patient_df = full_label_df.loc[(full_label_df['patient_id'] == patient) & (full_label_df['ground_truth'] != "OTHER")]
#     print(patient_df)
    if len(patient_df.ground_truth.unique()) >= 4: 
        usable_patients.append(patient)

# %%
len(usable_patients)
# Out:
# 122

# %%
usable_patient_df = full_label_df.loc[(full_label_df['patient_id'].isin(usable_patients)) & 
                                      (full_label_df['ground_truth'] != "OTHER")].copy()

# %%
usable_patient_df
# Out:
#      ground_truth                                              image  \
# 13            T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 14             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 15            T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 16             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 17       T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 18             T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 21       T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 22             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 23             T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 26             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 27            T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 28            T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 29             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 30             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 36             T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 37            T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 39       T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 40             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 41            T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 42             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 43            T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 44             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 45             T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 46       T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 47             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 48            T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 50             T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 52            T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 53             T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 54       T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# ...           ...                                                ...
# 3687           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 3689           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 3690           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 3691          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3692           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 3693          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3695     T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 3696     T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 3697           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 3698          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3721     T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 3727          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3729           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 3730           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 3731          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3732          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3735           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 3738          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3743           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 3744          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3746     T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 3747           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 3749          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3750          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3751          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 3752           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 3754           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 3755     T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 3756           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 3757          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
#
#                                       sd    patient_id  \
# 13       701-BRAIN_WWO_T1_COR_POST-08207  TCGA-14-0865
# 14         301-BRAIN_WWO_T1_AX_PRE-13193  TCGA-14-0865
# 15        601-BRAIN_WWO_T1_AX_POST-95894  TCGA-14-0865
# 16       201-BRAIN_WWO_T1_SAG_23SL-32502  TCGA-14-0865
# 17          501-BRAIN_WWO_FLAIR_AX-67274  TCGA-14-0865
# 3743   12-FSE_Tractography_Stealth-12040  TCGA-08-0360
# 3744                  6-3D_SPGR_AX-57389  TCGA-08-0360
# 3746                7-AX_FLAIR_gad-51944  TCGA-08-0360
# 3747                   1-FSPGR_SAG-11415  TCGA-08-0360
# 3749                 7-COR_T1_POST-12584  TCGA-02-0037
# 3750         9-3D_WAND_T1_WEIGHTED-11352  TCGA-02-0037
# 3751                  6-AX_T1_POST-64479  TCGA-02-0037
# 3752        10-2D_WAND_T2_WEIGHTED-02193  TCGA-02-0037
# 3754                       5-AX_T1-92259  TCGA-02-0037
# 3755                    4-AX_FLAIR-95660  TCGA-02-0037
# 3756                   3-AX_T2_FSE-69544  TCGA-02-0037
# 3757                 8-SAG_T1_POST-08358  TCGA-02-0037
#
#                                          exam_id
# 13    06-04-1995-MRI_BRAIN_W_WOUT_CONTRAST-31488
# 14    06-04-1995-MRI_BRAIN_W_WOUT_CONTRAST-31488
# 15    06-04-1995-MRI_BRAIN_W_WOUT_CONTRAST-31488
# 16    06-04-1995-MRI_BRAIN_W_WOUT_CONTRAST-31488
# 17    06-04-1995-MRI_BRAIN_W_WOUT_CONTRAST-31488
# 18    06-04-1995-MRI_BRAIN_W_WOUT_CONTRAST-31488
# 21    11-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-06737
# 22    11-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-06737
# 23    11-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-06737
# 26    11-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-06737
# 27    11-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-06737
# 28    11-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-06737
# 29    09-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-18668
# 30    09-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-18668
# 36    03-20-1995-MRI_BRAIN_W_WOUT_CONTRAST-54713
# 37    03-20-1995-MRI_BRAIN_W_WOUT_CONTRAST-54713
# 39    03-20-1995-MRI_BRAIN_W_WOUT_CONTRAST-54713
# 40    03-20-1995-MRI_BRAIN_W_WOUT_CONTRAST-54713
# 41    03-20-1995-MRI_BRAIN_W_WOUT_CONTRAST-54713
# 42    03-20-1995-MRI_BRAIN_W_WOUT_CONTRAST-54713
# 43    07-28-1995-MRI_BRAIN_W_WOUT_CONTRAST-19998
# 44    07-28-1995-MRI_BRAIN_W_WOUT_CONTRAST-19998
# 45    07-28-1995-MRI_BRAIN_W_WOUT_CONTRAST-19998
# 46    07-28-1995-MRI_BRAIN_W_WOUT_CONTRAST-19998
# 47    07-28-1995-MRI_BRAIN_W_WOUT_CONTRAST-19998
# 48    07-28-1995-MRI_BRAIN_W_WOUT_CONTRAST-19998
# 50    02-01-1996-MRI_BRAIN_W_WOUT_CONTRAST-11648
# 52    02-01-1996-MRI_BRAIN_W_WOUT_CONTRAST-11648
# 53    02-01-1996-MRI_BRAIN_W_WOUT_CONTRAST-11648
# 54    02-01-1996-MRI_BRAIN_W_WOUT_CONTRAST-11648
# ...                                          ...
# 3687                05-25-2000-HeadRoutine-98902
# 3689                05-25-2000-HeadRoutine-98902
# 3690                05-25-2000-HeadRoutine-98902
# 3691                05-25-2000-HeadRoutine-98902
# 3692                05-25-2000-HeadRoutine-98902
# 3693                05-25-2000-HeadRoutine-98902
# 3695                05-25-2000-HeadRoutine-98902
# 3696                05-25-2000-HeadRoutine-98902
# 3697                05-25-2000-HeadRoutine-98902
# 3698                05-25-2000-HeadRoutine-98902
# 3721           12-10-2002-NR_MRI_BRAIN_WWO-21815
# 3727           12-10-2002-NR_MRI_BRAIN_WWO-21815
# 3729           12-10-2002-NR_MRI_BRAIN_WWO-21815
# 3730           12-10-2002-NR_MRI_BRAIN_WWO-21815
# 3731           12-10-2002-NR_MRI_BRAIN_WWO-21815
# 3732           12-10-2002-NR_MRI_BRAIN_WWO-21815
# 3735               02-23-2003-MSTEALTH-DTI-31064
# 3738               02-23-2003-MSTEALTH-DTI-31064
# 3743               02-23-2003-MSTEALTH-DTI-31064
# 3744               02-23-2003-MSTEALTH-DTI-31064
# 3746               02-23-2003-MSTEALTH-DTI-31064
# 3747               02-23-2003-MSTEALTH-DTI-31064
# 3749     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3750     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3751     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3752     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3754     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3755     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3756     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
# 3757     01-13-1998-MRI_BRAIN_WWO_CONTRAMR-61567
#
# [1810 rows x 5 columns]

# %%
usable_patient_df['fixed_vol']  = ['' for x in usable_patient_df['ground_truth']]

# %%
for idx, row in usable_patient_df.iterrows():
    patient = row['patient_id']
    patient_df = usable_patient_df.loc[(full_label_df['patient_id'] == patient) & (full_label_df['ground_truth'] != "OTHER")]
    if 'T1' in patient_df['ground_truth'].unique(): 
        t1_df = patient_df[patient_df['ground_truth'] == "T1"]
        if t1_df.shape[0] > 1: 
            for idx, row1 in t1_df.iterrows(): 
                if 'ax' in row1['sd'].lower(): 
                    fixed_vol = row1['image']
                    break 
                else: 
                    fixed_vol = row1['image']
        else: 
            fixed_vol = list(t1_df['image'])[0]
    
    row['fixed_vol'] = fixed_vol

# %%
usable_patient_df.head(20)
# Out:
#    ground_truth                                              image  \
# 13          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 14           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 15          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 16           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 17     T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 18           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 21     T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 22           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 23           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 26           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 27          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 28          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 29           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 30           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 36           T2  /working/lupolab/julia/tcia_analysis/datasets/...
# 37          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 39     T2_FLAIR  /working/lupolab/julia/tcia_analysis/datasets/...
# 40           T1  /working/lupolab/julia/tcia_analysis/datasets/...
# 41          T1C  /working/lupolab/julia/tcia_analysis/datasets/...
# 42           T1  /working/lupolab/julia/tcia_analysis/datasets/...
#
#                                    sd    patient_id  \
# 13    701-BRAIN_WWO_T1_COR_POST-08207  TCGA-14-0865
# 14      301-BRAIN_WWO_T1_AX_PRE-13193  TCGA-14-0865
# 15     601-BRAIN_WWO_T1_AX_POST-95894  TCGA-14-0865
# 16    201-BRAIN_WWO_T1_SAG_23SL-32502  TCGA-14-0865
# 17       501-BRAIN_WWO_FLAIR_AX-67274  TCGA-14-0865
# 18    401-BRAIN_WWO_T2_AX_GRASE-74294  TCGA-14-0865
# 21       501-BRAIN_WOW_FLAIR_AX-76993  TCGA-14-0865
# 22         201-BRAIN_WOW_T1_SAG-03766  TCGA-14-0865
# 23    601-BRAIN_WOW_T2_GRASE_AX-27643  TCGA-14-0865
# 26      401-BRAIN_WOW_AX_T1_PRE-74074  TCGA-14-0865
# 27     701-BRAIN_WOW_AX_T1_POST-93808  TCGA-14-0865
# 28    801-BRAIN_WOW_COR_T1_POST-94144  TCGA-14-0865
# 29       301-PHOTON_____GADO_T1-55090  TCGA-14-0865
# 30  201-PHOTON_____T1_HEADFRAME-53776  TCGA-14-0865
# 36    401-BRAIN_WOW_T2_GRASE_AX-51305  TCGA-14-0865
# 37    701-BRAIN_WOW_COR_T1_POST-58903  TCGA-14-0865
# 39       301-BRAIN_WOW_FLAIR_AX-70793  TCGA-14-0865
# 40      501-BRAIN_WOW_AX_T1_PRE-39095  TCGA-14-0865
# 41     601-BRAIN_WOW_AX_T1_POST-60276  TCGA-14-0865
# 42         201-BRAIN_WOW_T1_SAG-39049  TCGA-14-0865
#
#                                        exam_id  \
# 13  06-04-1995-MRI_BRAIN_W_WOUT_CONTRAST-31488
# 14  06-04-1995-MRI_BRAIN_W_WOUT_CONTRAST-31488
# 15  06-04-1995-MRI_BRAIN_W_WOUT_CONTRAST-31488
# 16  06-04-1995-MRI_BRAIN_W_WOUT_CONTRAST-31488
# 17  06-04-1995-MRI_BRAIN_W_WOUT_CONTRAST-31488
# 18  06-04-1995-MRI_BRAIN_W_WOUT_CONTRAST-31488
# 21  11-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-06737
# 22  11-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-06737
# 23  11-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-06737
# 26  11-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-06737
# 27  11-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-06737
# 28  11-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-06737
# 29  09-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-18668
# 30  09-23-1995-MRI_BRAIN_W_WOUT_CONTRAST-18668
# 36  03-20-1995-MRI_BRAIN_W_WOUT_CONTRAST-54713
# 37  03-20-1995-MRI_BRAIN_W_WOUT_CONTRAST-54713
# 39  03-20-1995-MRI_BRAIN_W_WOUT_CONTRAST-54713
# 40  03-20-1995-MRI_BRAIN_W_WOUT_CONTRAST-54713
# 41  03-20-1995-MRI_BRAIN_W_WOUT_CONTRAST-54713
# 42  03-20-1995-MRI_BRAIN_W_WOUT_CONTRAST-54713
#
#                                             fixed_vol
# 13  /working/lupolab/julia/tcia_analysis/datasets/...
# 14  /working/lupolab/julia/tcia_analysis/datasets/...
# 15  /working/lupolab/julia/tcia_analysis/datasets/...
# 16  /working/lupolab/julia/tcia_analysis/datasets/...
# 17  /working/lupolab/julia/tcia_analysis/datasets/...
# 18  /working/lupolab/julia/tcia_analysis/datasets/...
# 21  /working/lupolab/julia/tcia_analysis/datasets/...
# 22  /working/lupolab/julia/tcia_analysis/datasets/...
# 23  /working/lupolab/julia/tcia_analysis/datasets/...
# 26  /working/lupolab/julia/tcia_analysis/datasets/...
# 27  /working/lupolab/julia/tcia_analysis/datasets/...
# 28  /working/lupolab/julia/tcia_analysis/datasets/...
# 29  /working/lupolab/julia/tcia_analysis/datasets/...
# 30  /working/lupolab/julia/tcia_analysis/datasets/...
# 36  /working/lupolab/julia/tcia_analysis/datasets/...
# 37  /working/lupolab/julia/tcia_analysis/datasets/...
# 39  /working/lupolab/julia/tcia_analysis/datasets/...
# 40  /working/lupolab/julia/tcia_analysis/datasets/...
# 41  /working/lupolab/julia/tcia_analysis/datasets/...
# 42  /working/lupolab/julia/tcia_analysis/datasets/...

# %%
usable_patient_df.to_csv('/working/lupolab/julia/tcia_analysis/code/usable_patient_gbm.csv')

# %% [markdown]
# Now that we finally have the fixed volume we want to align to for each image in each patient that we care about, let's go ahead and create the commands for brainsfit in brackets so that we can send them to the grid:

# %% [markdown]
# `BRAINSFit --fixedVolume $fixed_vol.nii.gz --movingVolume $moving_vol.nii.gz --outputVolume $output_vol.nii.gz --outputTransform $transform_output.tfm  --transformType Rigid`

# %%
commands = []
for idx, row in usable_patient_df.iterrows(): 
    fixed_vol = row['fixed_vol']
    moving_vol = row['image']
    output_vol = moving_vol.split('.n')[0]+'a'+'.nii.gz'
    command_align = 'BRAINSFit --fixedVolume '+fixed_vol+' --movingVolume '+moving_vol+' --outputVolume '+output_vol+' --transformType Rigid'
    commands.append(command_align)

# %%
os.chdir('/working/lupolab/julia/tcia_analysis/code/')

# %%
x = open('register_GBMs.txt', 'w')

# %%
x.write('{')
x.write('\n')
for command in commands: 
    x.write(command)
    x.write('\n')
x.write('}')
x.close()

# %%
# !grid_pipeline --scriptonly register_GBMs.txt
